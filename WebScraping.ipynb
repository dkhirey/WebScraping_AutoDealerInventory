# %% [markdown]
# # Webscraping Project - Deepak Khirey
# ## Notebook 1 - Webscraping using Beautifulsoup
# This notebook contains code to scrape Subarban Ford website "https://www.suburbanford.com/new-inventory/index.htm". This code is executed daily once to get car inventory data from website.

# %%
from urllib.parse import urlparse
from pprint import pprint
from urllib.parse import urlparse, parse_qs, parse_qsl
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.robotparser import RobotFileParser
import pandas as pd
from datetime import date
import os
import time

# %%
def getpagedata(url):
    # Requesting data from the website
    try:
        response = urlopen(url)
        page_content = response.read()
        bs = BeautifulSoup(page_content, 'lxml')
        return bs
        #print(bs.prettify())
    except Exception as e:
        print(e)

# %%
def scrapeallowed(url):
    # URL to Python's robots.txt files
    python_robot_url = url+ r'/robots.txt'
    #r'https://www.autotrader.com/robots.txt'

    # User-Agent
    user_agent = r'*' # '*' refers to all other bots

    # Create a RobotFileParser object
    # Pass Python's URL while creating the object
    python_robot_parser = RobotFileParser(python_robot_url)
    python_robot_parser.read()

    print('The robots file read is at:', python_robot_parser.url)

    valid_request = python_robot_parser.can_fetch(user_agent, url)
    print('The requested URL', url, 'can be crawled:', valid_request)
    return valid_request

# %%
def getclassvalue(tag,classname):
    value = None if tag.find(class_=classname) is None else tag.find(class_=classname).getText()
    return value

# %%
def getdetails(bs):
    header_class_elems = bs.find_all(class_='hproduct auto ford') 
    #pprint(header_class_elems)  
    for element in header_class_elems:
        data = {}
        name = element.find('h3').getText()
        pricing = element.find(class_='pricing multiple-prices list-unstyled')
        #msrp = None if pricing.find(class_='msrp') is None else pricing.find(class_='msrp').getText()
        #abSub = None if pricing.find(class_='abSub') is None else pricing.find(class_='abSub').getText()
        #internetPrice = None if pricing.find(class_='internetPrice') is None else pricing.find(class_='internetPrice').getText()
        #finalPrice = None if pricing.find(class_='stackedFinal final-price') is None else pricing.find(class_='stackedFinal final-price').getText()
        #print(name,msrp,abSub,internetPrice,finalPrice)
        data['scrapeDate']=date.today().strftime("%d/%m/%Y")
        data['name'] = name
        data['msrp'] = getclassvalue(pricing,'msrp')
        data['abSub'] = getclassvalue(pricing,'abSub')
        data['internetPrice'] = getclassvalue(pricing,'internetPrice')
        data['finalPrice'] = getclassvalue(pricing,'finalPrice')
        description = None if element.find(class_='description') is None else element.find(class_='description')
        #description = element.find(class_='description').find_all(['dt','dd'])
        #print(description)
        for dt_el, dd_el in zip(*(iter(description.find_all(['dt','dd'])),) * 2):
            data[dt_el.text] = dd_el.text
            #print(dt_el.text,"......",dd_el.text)
        #print(data)
        inventory.append(data)
    #return inventory

# %%
def writedata(inventory,filename):
    inventoryDF = pd.DataFrame(inventory)
    inventoryDF.sort_values('VIN: ',inplace=True)
    path = os.getcwd()+"/data/"+filename
    inventoryDF.to_csv(path,index=False)
    print('data written in '+path)

# %%
pages = [str(i) for i in range(0,1000,16)]
inventory = []
for page in pages:
    url = r'https://www.suburbanford.com/new-inventory/index.htm?start='+page+'&'
    print(url)
    if scrapeallowed(url):
        bs = getpagedata(url)
        getdetails(bs)
        filename = 'suburbanford_inventory_'+date.today().strftime("%d%m%Y")+'.csv'
        writedata(inventory,filename)
    else:
        print('scraping not allowed for this url...'+url)
    time.sleep(10)
# Out:
# https://www.suburbanford.com/new-inventory/index.htm?start=0&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=0&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=0& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=16&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=16&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=16& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=32&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=32&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=32& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=48&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=48&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=48& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=64&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=64&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=64& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=80&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=80&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=80& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=96&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=96&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=96& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=112&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=112&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=112& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=128&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=128&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=128& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=144&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=144&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=144& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=160&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=160&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=160& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=176&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=176&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=176& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=192&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=192&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=192& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=208&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=208&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=208& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=224&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=224&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=224& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=240&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=240&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=240& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=256&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=256&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=256& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=272&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=272&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=272& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=288&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=288&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=288& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=304&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=304&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=304& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=320&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=320&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=320& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=336&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=336&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=336& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=352&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=352&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=352& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=368&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=368&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=368& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=384&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=384&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=384& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=400&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=400&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=400& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=416&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=416&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=416& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=432&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=432&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=432& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=448&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=448&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=448& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=464&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=464&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=464& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=480&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=480&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=480& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=496&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=496&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=496& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=512&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=512&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=512& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=528&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=528&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=528& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=544&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=544&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=544& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=560&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=560&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=560& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=576&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=576&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=576& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=592&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=592&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=592& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=608&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=608&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=608& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=624&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=624&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=624& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=640&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=640&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=640& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=656&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=656&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=656& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=672&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=672&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=672& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=688&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=688&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=688& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=704&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=704&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=704& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=720&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=720&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=720& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=736&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=736&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=736& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=752&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=752&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=752& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=768&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=768&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=768& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=784&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=784&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=784& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=800&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=800&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=800& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=816&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=816&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=816& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=832&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=832&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=832& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=848&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=848&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=848& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=864&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=864&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=864& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=880&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=880&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=880& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=896&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=896&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=896& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=912&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=912&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=912& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=928&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=928&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=928& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=944&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=944&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=944& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=960&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=960&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=960& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=976&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=976&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=976& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
# https://www.suburbanford.com/new-inventory/index.htm?start=992&
# The robots file read is at: https://www.suburbanford.com/new-inventory/index.htm?start=992&/robots.txt
# The requested URL https://www.suburbanford.com/new-inventory/index.htm?start=992& can be crawled: True
# data written in C:\Users\t7659dk\Documents\Deepak\mydata\IUMSDS\Semester 7 - Fall 2019\Web Scraping\Project/data/suburbanford_inventory_03112019.csv
